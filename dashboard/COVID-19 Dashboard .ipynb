        var_name="Date", 
        value_name="value")

# %%
x
# Out:
#               Country/Region              type     Date  value
# 0                Afghanistan  confirmed global  1/22/20      0
# 1                    Albania  confirmed global  1/22/20      0
# 2                    Algeria  confirmed global  1/22/20      0
# 3                    Andorra  confirmed global  1/22/20      0
# 4                     Angola  confirmed global  1/22/20      0
# ...                      ...               ...      ...    ...
# 62395                 France  recovered global  4/10/20      0
# 62396            South Sudan  recovered global  4/10/20      0
# 62397         Western Sahara  recovered global  4/10/20      0
# 62398  Sao Tome and Principe  recovered global  4/10/20      0
# 62399                  Yemen  recovered global  4/10/20      0
#
# [62400 rows x 4 columns]

# %%
g = sns.pairplot(x, hue="type",  height=10,x_vars=["Date"],
                 y_vars=["value"])

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.despine(left=True)

# Generate a random univariate dataset
d = rs.normal(size=100)

# Plot a simple histogram with binsize determined automatically
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])

# Plot a kernel density estimate and rug plot
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])

# Plot a filled kernel density estimate
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])

# Plot a histogram and kernel density estimate
sns.distplot(d, color="m", ax=axes[1, 1])

plt.setp(axes, yticks=[])
plt.tight_layout()

# %%
d
# Out:
# array([ 1.3315865 ,  0.71527897, -1.54540029, -0.00838385,  0.62133597,
#        -0.72008556,  0.26551159,  0.10854853,  0.00429143, -0.17460021,
#         0.43302619,  1.20303737, -0.96506567,  1.02827408,  0.22863013,
#         0.44513761, -1.13660221,  0.13513688,  1.484537  , -1.07980489,
#        -1.97772828, -1.7433723 ,  0.26607016,  2.38496733,  1.12369125,
#         1.67262221,  0.09914922,  1.39799638, -0.27124799,  0.61320418,
#        -0.26731719, -0.54930901,  0.1327083 , -0.47614201,  1.30847308,
#         0.19501328,  0.40020999, -0.33763234,  1.25647226, -0.7319695 ,
#         0.66023155, -0.35087189, -0.93943336, -0.48933722, -0.80459114,
#        -0.21269764, -0.33914025,  0.31216994,  0.56515267, -0.14742026,
#        -0.02590534,  0.2890942 , -0.53987907,  0.70816002,  0.84222474,
#         0.2035808 ,  2.39470366,  0.91745894, -0.11227247, -0.36218045,
#        -0.23218226, -0.5017289 ,  1.12878515, -0.69781003, -0.08112218,
# ...
